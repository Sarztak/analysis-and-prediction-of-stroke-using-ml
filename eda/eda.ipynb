# %% [markdown]
# | Feature            | Type        | Description                            | Source / Transformation |
# | ------------------ | ----------- | -------------------------------------- | ----------------------- |
# | age                | numeric     | Age in years                           | raw                     |
# | age_group          | categorical | Age bands (0–30,30–60,60+)             | domain                  |
# | age_over_60        | binary      | Indicator if age>60                    | domain                  |
# | age_over_80        | binary      | Indicator if age>80                    | domain                  |
# | avg_glucose_level  | numeric     | Average glucose                        | raw                     |
# | glucose_group      | categorical | normal / elevated / high               | domain                  |
# | glucose_above_150  | binary      | >150 mg/dL                             | domain                  |
# | glucose_above_250  | binary      | >250 mg/dL                             | domain                  |
# | bmi                | numeric     | Body mass index                        | imputed                 |
# | bmi_category       | categorical | BMI group                              | domain                  |
# | is_overweight      | binary      | BMI > 25                               | domain                  |
# | is_bmi_missing     | binary      | BMI originally missing                 | domain                  |
# | gender             | categorical | {Male,Female}                          | cleaned                 |
# | work_type          | categorical | {Private,Self-employed,Govt_job,Other} | merged                  |
# | residence_type     | categorical | {Urban,Rural}                          | raw                     |
# | ever_married       | categorical | {Yes,No}                               | raw                     |
# | hypertension       | binary      | 1/0                                    | raw                     |
# | heart_disease      | binary      | 1/0                                    | raw                     |
# | smoking_status     | categorical | {never,formerly,smokes,Unknown}        | cleaned                 |
# | is_smoking_unknown | binary      | 1 if Unknown                           | derived                 |
